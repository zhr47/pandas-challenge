# %%
import pandas as pd

#load and read csv
csv_path = "Resources/purchase_data.csv"
purchase_data = pd.read_csv(csv_path)

# %%
# Player count
player_count = len(purchase_data["SN"].value_counts())

playercount = pd.DataFrame({"Total Players":[player_count]})
playercount
# Out:
#    Total Players
# 0            576

# %%
# Purchasing Analysis (Total)
# Number of Unique Items
unique_items = len(purchase_data["Item Name"].unique())
    
# Average Purchase Price
avg_price = purchase_data["Price"].mean()

# Total Number of Purchases
total_pur = len(purchase_data["Purchase ID"])

# Total Revenue
total_rev = purchase_data["Price"].sum()

purchase_analysis = pd.DataFrame({"Number of Unique Items": [unique_items], 
                                  "Average Price": avg_price, 
                                  "Total Number of Purchases": total_pur, 
                                  "Total Revenue": total_rev})
# Formating
purchase_analysis["Average Price"] = purchase_analysis["Average Price"].map("${:.2f}".format)
purchase_analysis["Total Revenue"] = purchase_analysis["Total Revenue"].map("${:.2f}".format)
purchase_analysis
# Out:
#    Number of Unique Items Average Price  Total Number of Purchases  \
# 0                     179         $3.05                        780
#
#   Total Revenue
# 0      $2379.77

# %%
# Gender Demographics
gender_stats = purchase_data.groupby("Gender")

# Count the total of screen names "SN" by gender
TCG = gender_stats.nunique()["SN"]

# Total count by gender and divivde by total players 
percentage_of_players = (TCG / player_count) * 100

# Create data frame
gender_demographics = pd.DataFrame({"Percentage of Players": percentage_of_players,
                                    "Total Count": TCG})

# Remove index
gender_demographics.index.name = None

# Format values
gender_demographics.sort_values(["Total Count"], 
                                ascending = False).style.format({"Percentage of Players":"{:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_da16f25a_c46b_11ea_b50b_8c859078c8b5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Percentage of Players</th>        <th class="col_heading level0 col1" >Total Count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_da16f25a_c46b_11ea_b50b_8c859078c8b5level0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_da16f25a_c46b_11ea_b50b_8c859078c8b5row0_col0" class="data row0 col0" >84.03</td>
#                         <td id="T_da16f25a_c46b_11ea_b50b_8c859078c8b5row0_col1" class="data row0 col1" >484</td>
#             </tr>
#             <tr>
#                         <th id="T_da16f25a_c46b_11ea_b50b_8c859078c8b5level0_row1" class="row_heading level0 row1" >Female</th>
#                         <td id="T_da16f25a_c46b_11ea_b50b_8c859078c8b5row1_col0" class="data row1 col0" >14.06</td>
#                         <td id="T_da16f25a_c46b_11ea_b50b_8c859078c8b5row1_col1" class="data row1 col1" >81</td>
#             </tr>
#             <tr>
#                         <th id="T_da16f25a_c46b_11ea_b50b_8c859078c8b5level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_da16f25a_c46b_11ea_b50b_8c859078c8b5row2_col0" class="data row2 col0" >1.91</td>
#                         <td id="T_da16f25a_c46b_11ea_b50b_8c859078c8b5row2_col1" class="data row2 col1" >11</td>
#             </tr>
#     </tbody></table>

# %%
# Purchasing Analysis (Gender)

# Purchase Count
purchase_count = gender_stats["Purchase ID"].count()

# Average purchase price
avg_purchase_price = gender_stats["Price"].mean()

# Average purchase total 
avg_purchase_total = gender_stats["Price"].sum()

# Average purchase total by gender divivded by purchase count 
avg_purchase_per_person = avg_purchase_total/TCG

# Create the data frame
gender_demographics = pd.DataFrame({"Purchase Count": purchase_count, 
                                    "Average Purchase Price": avg_purchase_price,
                                    "Average Purchase Value":avg_purchase_total,
                                    "Avg Purchase Total per Person": avg_purchase_per_person})

# Add "Gender"
gender_demographics.index.name = "Gender"

# Format table
gender_demographics.style.format({"Average Purchase Value":"${:,.2f}",
                                  "Average Purchase Price":"${:,.2f}",
                                  "Avg Purchase Total per Person":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Average Purchase Value</th>        <th class="col_heading level0 col3" >Avg Purchase Total per Person</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5row0_col0" class="data row0 col0" >113</td>
#                         <td id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5row0_col1" class="data row0 col1" >$3.20</td>
#                         <td id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5row0_col2" class="data row0 col2" >$361.94</td>
#                         <td id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5row0_col3" class="data row0 col3" >$4.47</td>
#             </tr>
#             <tr>
#                         <th id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5level0_row1" class="row_heading level0 row1" >Male</th>
#                         <td id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5row1_col0" class="data row1 col0" >652</td>
#                         <td id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5row1_col1" class="data row1 col1" >$3.02</td>
#                         <td id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5row1_col2" class="data row1 col2" >$1,967.64</td>
#                         <td id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5row1_col3" class="data row1 col3" >$4.07</td>
#             </tr>
#             <tr>
#                         <th id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5row2_col1" class="data row2 col1" >$3.35</td>
#                         <td id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5row2_col2" class="data row2 col2" >$50.19</td>
#                         <td id="T_da1b0052_c46b_11ea_8c26_8c859078c8b5row2_col3" class="data row2 col3" >$4.56</td>
#             </tr>
#     </tbody></table>

# %%
# Age Demographics

# The below each broken into bins of 4 years (i.e. &lt;10, 10-14, 15-19, etc.)
age_bins = [0, 9.90, 14.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# Sort into bins
purchase_data["Age Group"] = pd.cut(purchase_data["Age"],age_bins, labels=group_names)
purchase_data

# Create data frame with "Age Group" and group it
age_grouped = purchase_data.groupby("Age Group")

# Count total players by age
total_count_age = age_grouped["SN"].nunique()

# Calculate percentages
percentage_by_age = (total_count_age/player_count) * 100

# Create data frame
age_demographics = pd.DataFrame({"Total Count": total_count_age,
                                 "Percentage of Players": percentage_by_age})

# Format data frame with no index
age_demographics.index.name = None

# Format percentages
age_demographics.style.format({"Percentage of Players":"{:,.2f}%"})
# Out:
# <style  type="text/css" >
# </style><table id="T_da1e9118_c46b_11ea_b919_8c859078c8b5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_da1e9118_c46b_11ea_b919_8c859078c8b5level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row0_col0" class="data row0 col0" >17</td>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row0_col1" class="data row0 col1" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_da1e9118_c46b_11ea_b919_8c859078c8b5level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row1_col0" class="data row1 col0" >22</td>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row1_col1" class="data row1 col1" >3.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_da1e9118_c46b_11ea_b919_8c859078c8b5level0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row2_col0" class="data row2 col0" >107</td>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row2_col1" class="data row2 col1" >18.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_da1e9118_c46b_11ea_b919_8c859078c8b5level0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row3_col0" class="data row3 col0" >258</td>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row3_col1" class="data row3 col1" >44.79%</td>
#             </tr>
#             <tr>
#                         <th id="T_da1e9118_c46b_11ea_b919_8c859078c8b5level0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row4_col0" class="data row4 col0" >77</td>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row4_col1" class="data row4 col1" >13.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_da1e9118_c46b_11ea_b919_8c859078c8b5level0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row5_col0" class="data row5 col0" >52</td>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row5_col1" class="data row5 col1" >9.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_da1e9118_c46b_11ea_b919_8c859078c8b5level0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row6_col0" class="data row6 col0" >31</td>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row6_col1" class="data row6 col1" >5.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_da1e9118_c46b_11ea_b919_8c859078c8b5level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row7_col0" class="data row7 col0" >12</td>
#                         <td id="T_da1e9118_c46b_11ea_b919_8c859078c8b5row7_col1" class="data row7 col1" >2.08%</td>
#             </tr>
#     </tbody></table>

# %%
# Purchasing Analysis By Age Group

# Purchases
purchase_count_age = age_grouped["Purchase ID"].count()

# Average purchase price 
avg_purchase_price_age = age_grouped["Price"].mean()

# Total purchase value 
total_purchase_value = age_grouped["Price"].sum()

# Average purchase per person 
avg_purchase_per_person_age = total_purchase_value/total_count_age

# Create data frame
age_demographics = pd.DataFrame({"Purchase Count": purchase_count_age,
                                 "Average Purchase Price": avg_purchase_price_age,
                                 "Total Purchase Value":total_purchase_value,
                                 "Average Purchase Total per Person": avg_purchase_per_person_age})

# Format data frame with no index
age_demographics.index.name = None

# Format with currency style
age_demographics.style.format({"Average Purchase Price":"${:,.2f}",
                               "Total Purchase Value":"${:,.2f}",
                               "Average Purchase Total per Person":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Average Purchase Total per Person</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row0_col0" class="data row0 col0" >23</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row0_col1" class="data row0 col1" >$3.35</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row0_col2" class="data row0 col2" >$77.13</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row0_col3" class="data row0 col3" >$4.54</td>
#             </tr>
#             <tr>
#                         <th id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row1_col0" class="data row1 col0" >28</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row1_col1" class="data row1 col1" >$2.96</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row1_col2" class="data row1 col2" >$82.78</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row1_col3" class="data row1 col3" >$3.76</td>
#             </tr>
#             <tr>
#                         <th id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5level0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row2_col0" class="data row2 col0" >136</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row2_col1" class="data row2 col1" >$3.04</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row2_col2" class="data row2 col2" >$412.89</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row2_col3" class="data row2 col3" >$3.86</td>
#             </tr>
#             <tr>
#                         <th id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5level0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row3_col0" class="data row3 col0" >365</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row3_col1" class="data row3 col1" >$3.05</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row3_col2" class="data row3 col2" >$1,114.06</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row3_col3" class="data row3 col3" >$4.32</td>
#             </tr>
#             <tr>
#                         <th id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5level0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row4_col0" class="data row4 col0" >101</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row4_col1" class="data row4 col1" >$2.90</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row4_col2" class="data row4 col2" >$293.00</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row4_col3" class="data row4 col3" >$3.81</td>
#             </tr>
#             <tr>
#                         <th id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5level0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row5_col0" class="data row5 col0" >73</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row5_col1" class="data row5 col1" >$2.93</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row5_col2" class="data row5 col2" >$214.00</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row5_col3" class="data row5 col3" >$4.12</td>
#             </tr>
#             <tr>
#                         <th id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5level0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row6_col0" class="data row6 col0" >41</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row6_col1" class="data row6 col1" >$3.60</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row6_col2" class="data row6 col2" >$147.67</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row6_col3" class="data row6 col3" >$4.76</td>
#             </tr>
#             <tr>
#                         <th id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row7_col0" class="data row7 col0" >13</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row7_col1" class="data row7 col1" >$2.94</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row7_col2" class="data row7 col2" >$38.24</td>
#                         <td id="T_da21f062_c46b_11ea_9a6a_8c859078c8b5row7_col3" class="data row7 col3" >$3.19</td>
#             </tr>
#     </tbody></table>

# %%
# Top Spenders

# Group purchase data by screen names
purchase_stats = purchase_data.groupby("SN")

# Count the total purchases by name
purchase_count_spender = purchase_stats["Purchase ID"].count()

# Calculate the average purchase by name 
avg_purchase_price_spender = purchase_stats["Price"].mean()

# Calculate purchase total 
purchase_total_spender = purchase_stats["Price"].sum()

# Create data frame with obtained values
top_spenders = pd.DataFrame({"Purchase Count": purchase_count_spender,
                             "Average Purchase Price": avg_purchase_price_spender,
                             "Total Purchase Value":purchase_total_spender})

# Sort in descending order to obtain top 5 spender names 
formatted_spenders = top_spenders.sort_values(["Total Purchase Value"], 
                                              ascending=False).head()

# Format with currency style
formatted_spenders.style.format({"Average Purchase Total":"${:,.2f}",
                                 "Average Purchase Price":"${:,.2f}", 
                                 "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_da25e508_c46b_11ea_9973_8c859078c8b5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_da25e508_c46b_11ea_9973_8c859078c8b5level0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_da25e508_c46b_11ea_9973_8c859078c8b5row0_col0" class="data row0 col0" >5</td>
#                         <td id="T_da25e508_c46b_11ea_9973_8c859078c8b5row0_col1" class="data row0 col1" >$3.79</td>
#                         <td id="T_da25e508_c46b_11ea_9973_8c859078c8b5row0_col2" class="data row0 col2" >$18.96</td>
#             </tr>
#             <tr>
#                         <th id="T_da25e508_c46b_11ea_9973_8c859078c8b5level0_row1" class="row_heading level0 row1" >Idastidru52</th>
#                         <td id="T_da25e508_c46b_11ea_9973_8c859078c8b5row1_col0" class="data row1 col0" >4</td>
#                         <td id="T_da25e508_c46b_11ea_9973_8c859078c8b5row1_col1" class="data row1 col1" >$3.86</td>
#                         <td id="T_da25e508_c46b_11ea_9973_8c859078c8b5row1_col2" class="data row1 col2" >$15.45</td>
#             </tr>
#             <tr>
#                         <th id="T_da25e508_c46b_11ea_9973_8c859078c8b5level0_row2" class="row_heading level0 row2" >Chamjask73</th>
#                         <td id="T_da25e508_c46b_11ea_9973_8c859078c8b5row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_da25e508_c46b_11ea_9973_8c859078c8b5row2_col1" class="data row2 col1" >$4.61</td>
#                         <td id="T_da25e508_c46b_11ea_9973_8c859078c8b5row2_col2" class="data row2 col2" >$13.83</td>
#             </tr>
#             <tr>
#                         <th id="T_da25e508_c46b_11ea_9973_8c859078c8b5level0_row3" class="row_heading level0 row3" >Iral74</th>
#                         <td id="T_da25e508_c46b_11ea_9973_8c859078c8b5row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_da25e508_c46b_11ea_9973_8c859078c8b5row3_col1" class="data row3 col1" >$3.40</td>
#                         <td id="T_da25e508_c46b_11ea_9973_8c859078c8b5row3_col2" class="data row3 col2" >$13.62</td>
#             </tr>
#             <tr>
#                         <th id="T_da25e508_c46b_11ea_9973_8c859078c8b5level0_row4" class="row_heading level0 row4" >Iskadarya95</th>
#                         <td id="T_da25e508_c46b_11ea_9973_8c859078c8b5row4_col0" class="data row4 col0" >3</td>
#                         <td id="T_da25e508_c46b_11ea_9973_8c859078c8b5row4_col1" class="data row4 col1" >$4.37</td>
#                         <td id="T_da25e508_c46b_11ea_9973_8c859078c8b5row4_col2" class="data row4 col2" >$13.10</td>
#             </tr>
#     </tbody></table>

# %%
# Most Popular Items

# New data frame 
items = purchase_data[["Item ID", "Item Name", "Price"]]

# Group the item data
item_stats = items.groupby(["Item ID","Item Name"])

# Number of times an item has been purchased 
purchase_count_item = item_stats["Price"].count()

# Purchase value per item 
purchase_value = (item_stats["Price"].sum()) 

# Item price
item_price = purchase_value/purchase_count_item

# Data frame with values
most_popular_items = pd.DataFrame({"Purchase Count": purchase_count_item, 
                                   "Item Price": item_price,
                                   "Total Purchase Value":purchase_value})

# Top spenders and top 5 items in order
popular_formatted = most_popular_items.sort_values(["Purchase Count"], 
                                                   ascending=False).head()

# Format
popular_formatted.style.format({"Item Price":"${:,.2f}",
                                "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5level0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5level1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5row0_col1" class="data row0 col1" >$4.61</td>
#                         <td id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5row0_col2" class="data row0 col2" >$59.99</td>
#             </tr>
#             <tr>
#                         <th id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5level0_row1" class="row_heading level0 row1" >178</th>
#                         <th id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5level1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5row1_col1" class="data row1 col1" >$4.23</td>
#                         <td id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5row1_col2" class="data row1 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5level0_row2" class="row_heading level0 row2" >145</th>
#                         <th id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5level1_row2" class="row_heading level1 row2" >Fiery Glass Crusader</th>
#                         <td id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5row2_col0" class="data row2 col0" >9</td>
#                         <td id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5row2_col1" class="data row2 col1" >$4.58</td>
#                         <td id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5row2_col2" class="data row2 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5level0_row3" class="row_heading level0 row3" >132</th>
#                         <th id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5level1_row3" class="row_heading level1 row3" >Persuasion</th>
#                         <td id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5row3_col1" class="data row3 col1" >$3.22</td>
#                         <td id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5row3_col2" class="data row3 col2" >$28.99</td>
#             </tr>
#             <tr>
#                         <th id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5level0_row4" class="row_heading level0 row4" >108</th>
#                         <th id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5level1_row4" class="row_heading level1 row4" >Extraction, Quickblade Of Trembling Hands</th>
#                         <td id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5row4_col0" class="data row4 col0" >9</td>
#                         <td id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5row4_col1" class="data row4 col1" >$3.53</td>
#                         <td id="T_da29b734_c46b_11ea_a7fc_8c859078c8b5row4_col2" class="data row4 col2" >$31.77</td>
#             </tr>
#     </tbody></table>

# %%
# Most Profitable Items
popular_formatted = most_popular_items.sort_values(["Total Purchase Value"],
                                                   ascending=False).head()
# Format with currency style
popular_formatted.style.format({"Item Price":"${:,.2f}",
                                "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5level0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5level1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5row0_col1" class="data row0 col1" >$4.61</td>
#                         <td id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5row0_col2" class="data row0 col2" >$59.99</td>
#             </tr>
#             <tr>
#                         <th id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5level0_row1" class="row_heading level0 row1" >178</th>
#                         <th id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5level1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5row1_col1" class="data row1 col1" >$4.23</td>
#                         <td id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5row1_col2" class="data row1 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5level0_row2" class="row_heading level0 row2" >82</th>
#                         <th id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5level1_row2" class="row_heading level1 row2" >Nirvana</th>
#                         <td id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5row2_col0" class="data row2 col0" >9</td>
#                         <td id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5row2_col1" class="data row2 col1" >$4.90</td>
#                         <td id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5row2_col2" class="data row2 col2" >$44.10</td>
#             </tr>
#             <tr>
#                         <th id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5level0_row3" class="row_heading level0 row3" >145</th>
#                         <th id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5level1_row3" class="row_heading level1 row3" >Fiery Glass Crusader</th>
#                         <td id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5row3_col1" class="data row3 col1" >$4.58</td>
#                         <td id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5row3_col2" class="data row3 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5level0_row4" class="row_heading level0 row4" >103</th>
#                         <th id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5level1_row4" class="row_heading level1 row4" >Singed Scalpel</th>
#                         <td id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5row4_col0" class="data row4 col0" >8</td>
#                         <td id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5row4_col1" class="data row4 col1" >$4.35</td>
#                         <td id="T_da2cd476_c46b_11ea_bf08_8c859078c8b5row4_col2" class="data row4 col2" >$34.80</td>
#             </tr>
#     </tbody></table>
